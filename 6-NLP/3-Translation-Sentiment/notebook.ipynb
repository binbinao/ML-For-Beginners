# %%
from textblob import TextBlob

blob = TextBlob(
    "It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife!"
)
print(blob.translate(to="fr"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       1 from textblob import TextBlob
#       3 blob = TextBlob(
#       4     "It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife!"
#       5 )
# ----> 6 print(blob.translate(to="fr"))
#
# AttributeError: 'TextBlob' object has no attribute 'translate'

# %%
from googletrans import Translator

translator = Translator()

text = "It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife!"

result = translator.translate(text, dest="fr")
# Out:
# /var/folders/nr/mb6xd1fs5jsbhy5jf1lpn5340000gn/T/ipykernel_5624/3636003898.py:7: RuntimeWarning: coroutine 'Translator.translate' was never awaited
#   result = translator.translate(text, dest="fr")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
